# %% [markdown]
# <a href="https://colab.research.google.com/github/archananair17/Exam/blob/main/DecisionTreeReg_pynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('AAPL.csv')

# %%
x = dataset.iloc[:, :-1].values

# %%
y = dataset.iloc[:, -1].values

# %%
y = y.reshape(len(y),1)

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(x, y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
plt.scatter(x, y, color = 'red')
plt.plot(x, regressor.predict(x), color = 'blue')
plt.xlabel('Date')
plt.ylabel('Stockprice')
plt.show()
